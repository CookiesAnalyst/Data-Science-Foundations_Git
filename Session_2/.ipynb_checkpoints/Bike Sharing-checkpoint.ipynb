# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/sergi/Desktop/MBDA/Master/Data Science Foundations/Session_2/3_bike_sharing.csv")

# %%
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# 5      2011-01-01 05:00:00       1        0           0        2   9.84
# 6      2011-01-01 06:00:00       1        0           0        1   9.02
# 7      2011-01-01 07:00:00       1        0           0        1   8.20
# 8      2011-01-01 08:00:00       1        0           0        1   9.84
# 9      2011-01-01 09:00:00       1        0           0        1  13.12
# 10     2011-01-01 10:00:00       1        0           0        1  15.58
# 11     2011-01-01 11:00:00       1        0           0        1  14.76
# ...

# %%
df.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
df["datetime"].unique()
df["season"].unique()
df["holiday"].unique()
df["workingday"].unique()
df["weather"].unique()
df["temp"].unique()
df["atemp"].unique()
df["humidity"].unique()
df["windspeed"].unique()
df["casual"].unique()
df["registered"].unique()
df["count"].unique()
# Out:
# array([ 16,  40,  32,  13,   1,   2,   3,   8,  14,  36,  56,  84,  94,
#        106, 110,  93,  67,  35,  37,  34,  28,  39,  17,   9,   6,  20,
#         53,  70,  75,  59,  74,  76,  65,  30,  22,  31,   5,  64, 154,
#         88,  44,  51,  61,  77,  72, 157,  52,  12,   4, 179, 100,  42,
#         57,  78,  97,  63,  83, 212, 182, 112,  54,  48,  11,  33, 195,
#        115,  46,  79,  71,  62,  89, 190, 169, 132,  43,  19,  95, 219,
#        122,  45,  86, 172, 163,  69,  23,   7, 210, 134,  73,  50,  87,
#        187, 123,  15,  25,  98, 102,  55,  10,  49,  82,  92,  41,  38,
#        188,  47, 178, 155,  24,  18,  27,  99, 217, 130, 136,  29, 128,
#         81,  68, 139, 137, 202,  60, 162, 144, 158, 117,  90, 159, 101,
#        118, 129,  26, 104,  91, 113, 105,  21,  80, 125, 133, 197, 109,
#        161, 135, 116, 176, 168, 108, 103, 175, 147,  96, 220, 127, 205,
#        174, 121, 230,  66, 114, 216, 243, 152, 199,  58, 166, 170, 165,
# ...

# %%
df["datetime"].unique()
# Out:
# array(['2011-01-01 00:00:00', '2011-01-01 01:00:00', '2011-01-01 02:00:00',
#        ..., '2012-12-19 21:00:00', '2012-12-19 22:00:00',
#        '2012-12-19 23:00:00'], dtype=object)

# %%
df["season"].unique()
# Out:
# array([1, 2, 3, 4])

# %%
sum(df['season'] == 1)
# Out:
# 2686

# %%
sum(df['season'] == 2)
# Out:
# 2733

# %%
sum(df['season'] == 3)
# Out:
# 2733

# %%
sum(df['season'] == 4)
# Out:
# 2734

# %%
df.iloc[0:2685,:]
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# 5     2011-01-01 05:00:00       1        0           0        2   9.84
# 6     2011-01-01 06:00:00       1        0           0        1   9.02
# 7     2011-01-01 07:00:00       1        0           0        1   8.20
# 8     2011-01-01 08:00:00       1        0           0        1   9.84
# 9     2011-01-01 09:00:00       1        0           0        1  13.12
# 10    2011-01-01 10:00:00       1        0           0        1  15.58
# 11    2011-01-01 11:00:00       1        0           0        1  14.76
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
plt.figure(figsize=[12,10])
sns.factorplot ('season', 'count', 'registered', data=df, kind='bar', palette='muted', legend=False)
plt.show()

# %%
plt.figure(figsize=[12,10])
sns.countplot(df['season'])
plt.show()
