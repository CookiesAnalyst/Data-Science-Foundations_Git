# %% [markdown]
# # Subject: Data Science Foundation
#
# ## Session 13 - Correlation in Python.
#
# ### Assignment 1 -  Calculating Correlation for pandas Dataframe "Titanic"
#
#
# - Considering the Correlation analysis presented in Demo 1 develop a new one for the data set “Titanic”.
# - Select the variables most appropriate and justify your option.
# - Commit scripts in your GitHub account. You should export your your solution code (.ipynb notebook) and push it to your repository “DataScienceFoundations”.
# - The following are the tasks that should complete and synchronize with your repository “DataScienceFoundations” until November 23. Please notice that this task will not be graded, however it’s important that you correctly understand and complete them in order to be sure that you won’t have problems with further assignments.
#
# Guidelines:
# - Clone the Git repository to get an initial code:
# https://github.com/FGutierresBTS/BTS_MasterInBigData.git
# - Once you downloaded the repository to your local file system, go to the folder “BTS_MasterInBigData/ Session_13_DSF”.
# - Copy the folder “Session_13_DSF” into your local folder “DataScienceFoundations”.
# - In the folder “Session_13_DSF” you will see the files called:
#     -	BTS_DataScienceFoundations_Session13_Correlation_Individual_assignment.ipynb.
#     -   "1_titanic_dataset.csv" (note: this dataset must be pre-processed).
# - Import these files into Jupyter Notebook using the “Upload” button.
# - Open the imported script and put your code inside the notebook.
# - Export your Assignment *.ipynb notebook and push it to your repository “DataScienceFoundations”.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("1_titanic_dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# > Put your code here

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# We are not going to use:
#
#    1.- The number of 'Cabin' because it doesn't give you any relevant information as all values are uniques and there are excessive empty values (NaN).
#
#    2.- The name of every passenger. Doesn't determine anything.
#
#    3.- The passenger ID. Doesn't determine anything, neither.
#
#    4.- Ticket number. Doesn't determine anything, neither.
#
#    5.- Port embarked. Doesn't determine anything, neither.

# %%
df = df[['Survived', 'Pclass', 'Sex','Age', 'SibSp', "Parch", 'Fare']]

# %%
df.head() #it is necessary to transform in numbers male and female.
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
df['Sex'] = df['Sex'].map( {'female': 0, 'male': 1} ).astype(int)

# %%
df.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   14.526497    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df = df.dropna(axis=0)

# %%
df.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  714.000000  714.000000  714.000000  714.000000  714.000000  714.000000
# mean     0.406162    2.236695    0.634454   29.699118    0.512605    0.431373
# std      0.491460    0.838250    0.481921   14.526497    0.929783    0.853289
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    1.000000    0.000000   20.125000    0.000000    0.000000
# 50%      0.000000    2.000000    1.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000    1.000000
# max      1.000000    3.000000    1.000000   80.000000    5.000000    6.000000
#
#              Fare
# count  714.000000
# mean    34.694514
# std     52.918930
# min      0.000000
# 25%      8.050000
# 50%     15.741700
# 75%     33.375000
# max    512.329200

# %%
corr = df.corr(method='spearman')

# %%
corr
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.360656 -0.538826 -0.052565  0.073244  0.156444  0.339027
# Pclass   -0.360656  1.000000  0.159372 -0.361666 -0.050959 -0.018489 -0.730578
# Sex      -0.538826  0.159372  1.000000  0.083330 -0.164887 -0.254697 -0.274996
# Age      -0.052565 -0.361666  0.083330  1.000000 -0.182061 -0.254212  0.135051
# SibSp     0.073244 -0.050959 -0.164887 -0.182061  1.000000  0.426955  0.422994
# Parch     0.156444 -0.018489 -0.254697 -0.254212  0.426955  1.000000  0.407150
# Fare      0.339027 -0.730578 -0.274996  0.135051  0.422994  0.407150  1.000000

# %%
df.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col0 {
#             background-color:  #b40426;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col1 {
#             background-color:  #5e7de7;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col3 {
#             background-color:  #9ebeff;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col4 {
#             background-color:  #abc8fd;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col5 {
#             background-color:  #c4d5f3;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col6 {
#             background-color:  #e3d9d3;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col0 {
#             background-color:  #6282ea;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col1 {
#             background-color:  #b40426;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col2 {
#             background-color:  #d1dae9;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col3 {
#             background-color:  #5f7fe8;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col4 {
#             background-color:  #c0d4f5;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col5 {
#             background-color:  #b7cff9;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col6 {
#             background-color:  #3b4cc0;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col0 {
#             background-color:  #3b4cc0;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col1 {
#             background-color:  #cfdaea;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col2 {
#             background-color:  #b40426;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col3 {
#             background-color:  #c4d5f3;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col4 {
#             background-color:  #98b9ff;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col5 {
#             background-color:  #779af7;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col6 {
#             background-color:  #85a8fc;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row3_col0 {
#             background-color:  #80a3fa;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row3_col1 {
#             background-color:  #3b4cc0;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row3_col2 {
#             background-color:  #abc8fd;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row3_col3 {
#             background-color:  #b40426;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row3_col4 {
#             background-color:  #485fd1;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row3_col5 {
#             background-color:  #6384eb;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row3_col6 {
#             background-color:  #abc8fd;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row4_col0 {
#             background-color:  #82a6fb;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row4_col1 {
#             background-color:  #9abbff;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row4_col2 {
#             background-color:  #6b8df0;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row4_col3 {
#             background-color:  #3b4cc0;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row4_col4 {
#             background-color:  #b40426;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row4_col5 {
#             background-color:  #e4d9d2;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row4_col6 {
#             background-color:  #adc9fd;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row5_col0 {
#             background-color:  #94b6ff;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row5_col1 {
#             background-color:  #81a4fb;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row5_col2 {
#             background-color:  #3b4cc0;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row5_col3 {
#             background-color:  #485fd1;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row5_col4 {
#             background-color:  #dedcdb;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row5_col5 {
#             background-color:  #b40426;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row5_col6 {
#             background-color:  #b3cdfb;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row6_col0 {
#             background-color:  #e4d9d2;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row6_col1 {
#             background-color:  #3b4cc0;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row6_col2 {
#             background-color:  #88abfd;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row6_col3 {
#             background-color:  #c6d6f1;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row6_col4 {
#             background-color:  #cedaeb;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row6_col5 {
#             background-color:  #dadce0;
#         }    #T_be35193a_df18_11e7_b086_e4ce8f0e9568row6_col6 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_be35193a_df18_11e7_b086_e4ce8f0e9568" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Survived</th>
#         <th class="col_heading level0 col1" >Pclass</th>
#         <th class="col_heading level0 col2" >Sex</th>
#         <th class="col_heading level0 col3" >Age</th>
#         <th class="col_heading level0 col4" >SibSp</th>
#         <th class="col_heading level0 col5" >Parch</th>
#         <th class="col_heading level0 col6" >Fare</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_be35193a_df18_11e7_b086_e4ce8f0e9568" class="row_heading level0 row0" >Survived</th>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col0" class="data row0 col0" >1.0</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col1" class="data row0 col1" >-0.36</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col2" class="data row0 col2" >-0.54</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col3" class="data row0 col3" >-0.077</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col4" class="data row0 col4" >-0.017</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col5" class="data row0 col5" >0.093</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row0_col6" class="data row0 col6" >0.27</td>
#     </tr>    <tr>
#         <th id="T_be35193a_df18_11e7_b086_e4ce8f0e9568" class="row_heading level0 row1" >Pclass</th>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col0" class="data row1 col0" >-0.36</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col1" class="data row1 col1" >1.0</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col2" class="data row1 col2" >0.16</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col3" class="data row1 col3" >-0.37</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col4" class="data row1 col4" >0.067</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col5" class="data row1 col5" >0.026</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row1_col6" class="data row1 col6" >-0.55</td>
#     </tr>    <tr>
#         <th id="T_be35193a_df18_11e7_b086_e4ce8f0e9568" class="row_heading level0 row2" >Sex</th>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col0" class="data row2 col0" >-0.54</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col1" class="data row2 col1" >0.16</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col2" class="data row2 col2" >1.0</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col3" class="data row2 col3" >0.093</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col4" class="data row2 col4" >-0.1</td>
#         <td id="T_be35193a_df18_11e7_b086_e4ce8f0e9568row2_col5" cl

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# > Answer question here

# %% [markdown]
# As we can see, the best values to predict survival are:
#
#     Fare (0.27)
#     Sex (-0.54)
#     Pclass (-0.36)
#
# As more rich you are (Fare and PClass), more chances of get alive. Fare is positive because there are not negative prices. And Pclass is negatie because of 3 different classes, the first one is the richer.
#
# We can see too that sex is the best important feature to know if somebody is going to survive. As Females are 0, and Males 1, that means that females are the sex with the most proababilities of surviving.
