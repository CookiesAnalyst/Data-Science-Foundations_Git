# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("/Users/sergi/Desktop/MBDA/Master/Data Science Foundations/Session_1/file_formats/rural_population_data.csv")

# %%
df
# Out:
#          Continent                          ElevationZone  \
# 0           Africa    Elevations > 20m or Non-Contiguous
# 1           Africa    Elevations > 20m or Non-Contiguous
# 2           Africa  Elevations Less Than or Equal To 10m
# 3           Africa  Elevations Less Than or Equal To 10m
# 4           Africa  Elevations Less Than or Equal To 12m
# 5           Africa  Elevations Less Than or Equal To 12m
# 6           Africa    Elevations Less Than or Equal To 1m
# 7           Africa    Elevations Less Than or Equal To 1m
# 8           Africa  Elevations Less Than or Equal To 20m
# 9           Africa  Elevations Less Than or Equal To 20m
# 10          Africa    Elevations Less Than or Equal To 3m
# 11          Africa    Elevations Less Than or Equal To 3m
# 12          Africa    Elevations Less Than or Equal To 5m
# 13          Africa    Elevations Less Than or Equal To 5m
# 14          Africa    Elevations Less Than or Equal To 7m
# ...

# %%
df.head ()
# Out:
#   Continent                          ElevationZone UrbanRuralDesignation  \
# 0    Africa    Elevations > 20m or Non-Contiguous                  Rural
# 1    Africa    Elevations > 20m or Non-Contiguous                  Urban
# 2    Africa  Elevations Less Than or Equal To 10m                  Rural
# 3    Africa  Elevations Less Than or Equal To 10m                  Urban
# 4    Africa  Elevations Less Than or Equal To 12m                  Rural
#
#    Population1990  Population2000  Population2010  Population2100  LandArea
# 0       333302081       418265923       530184094      1249908321  23749644
# 1       157846329       210381843       266776037       504662423    204719
# 2        18167003        22569516        28154645        76368900    172460
# 3        22412955        28679117        36746774        94042536     13838
# 4        20569411        25576481        31957186        85839163    202456

# %%
df.to_string()
# Out:
# '         Continent                          ElevationZone UrbanRuralDesignation  Population1990  Population2000  Population2010  Population2100  LandArea\n0           Africa    Elevations > 20m or Non-Contiguous                  Rural       333302081       418265923       530184094      1249908321  23749644\n1           Africa    Elevations > 20m or Non-Contiguous                  Urban       157846329       210381843       266776037       504662423    204719\n2           Africa  Elevations Less Than or Equal To 10m                  Rural        18167003        22569516        28154645        76368900    172460\n3           Africa  Elevations Less Than or Equal To 10m                  Urban        22412955        28679117        36746774        94042536     13838\n4           Africa  Elevations Less Than or Equal To 12m                  Rural        20569411        25576481        31957186        85839163    202456\n5           Africa  Elevations Less Than or Equal To 12m           
# ...

# %%
print(df.to_string())
# Out:
#          Continent                          ElevationZone UrbanRuralDesignation  Population1990  Population2000  Population2010  Population2100  LandArea
# 0           Africa    Elevations > 20m or Non-Contiguous                  Rural       333302081       418265923       530184094      1249908321  23749644
# 1           Africa    Elevations > 20m or Non-Contiguous                  Urban       157846329       210381843       266776037       504662423    204719
# 2           Africa  Elevations Less Than or Equal To 10m                  Rural        18167003        22569516        28154645        76368900    172460
# 3           Africa  Elevations Less Than or Equal To 10m                  Urban        22412955        28679117        36746774        94042536     13838
# 4           Africa  Elevations Less Than or Equal To 12m                  Rural        20569411        25576481        31957186        85839163    202456
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#          Continent                          ElevationZone  \
# 0           Africa    Elevations > 20m or Non-Contiguous
# 1           Africa    Elevations > 20m or Non-Contiguous
# 2           Africa  Elevations Less Than or Equal To 10m
# 3           Africa  Elevations Less Than or Equal To 10m
# 4           Africa  Elevations Less Than or Equal To 12m
# 5           Africa  Elevations Less Than or Equal To 12m
# 6           Africa    Elevations Less Than or Equal To 1m
# 7           Africa    Elevations Less Than or Equal To 1m
# 8           Africa  Elevations Less Than or Equal To 20m
# 9           Africa  Elevations Less Than or Equal To 20m
# 10          Africa    Elevations Less Than or Equal To 3m
# 11          Africa    Elevations Less Than or Equal To 3m
# 12          Africa    Elevations Less Than or Equal To 5m
# 13          Africa    Elevations Less Than or Equal To 5m
# 14          Africa    Elevations Less Than or Equal To 7m
# ...

# %%
df.loc[:,"Continent"]=="Europe"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60      True
# 61      True
# 62      True
# 63      True
# 64      True
# 65      True
# ...

# %%
df.loc[df.loc[:,"Continent"]=="Europe"]
# Out:
#    Continent                          ElevationZone UrbanRuralDesignation  \
# 60    Europe    Elevations > 20m or Non-Contiguous                  Rural
# 61    Europe    Elevations > 20m or Non-Contiguous                  Urban
# 62    Europe  Elevations Less Than or Equal To 10m                  Rural
# 63    Europe  Elevations Less Than or Equal To 10m                  Urban
# 64    Europe  Elevations Less Than or Equal To 12m                  Rural
# 65    Europe  Elevations Less Than or Equal To 12m                  Urban
# 66    Europe    Elevations Less Than or Equal To 1m                 Rural
# 67    Europe    Elevations Less Than or Equal To 1m                 Urban
# 68    Europe  Elevations Less Than or Equal To 20m                  Rural
# 69    Europe  Elevations Less Than or Equal To 20m                  Urban
# 70    Europe    Elevations Less Than or Equal To 3m                 Rural
# 71    Europe    Elevations Less Than or Equal To 3m                 Urban
# ...

# %% [markdown]
# # 1. Find all unique values of the column "Continent"

# %%
df["Continent"].unique()
# Out:
# array(['Africa', 'Asia', 'Oceania', 'Europe', 'North America',
#        'South America'], dtype=object)

# %% [markdown]
# # 2. Calculate a grow rate based on this formula: Growrate = (Population2100 - Population2000) / Population2000

# %%
df['Population2100'].mean()
# Out:
# 202861325.46666667

# %%
df ['Population2000'].mean()
# Out:
# 120539097.45

# %%
growthrate = (df['Population2100'].mean() - df ['Population2000'].mean())/df ['Population2000'].mean()

# %%
growthrate
# Out:
# 0.6829504265270792

# %% [markdown]
# # 3. Create a histogram of “Growrate”

# %%
import matplotlib.pyplot as plt

# %%
df["Population2100"].hist()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #Work unfinished

# %% [markdown]
# # 4. Check the existence of NaN values in the DataFrame.

# %%
df.isnull ()
# Out:
#      Continent  ElevationZone  UrbanRuralDesignation  Population1990  \
# 0        False          False                  False           False
# 1        False          False                  False           False
# 2        False          False                  False           False
# 3        False          False                  False           False
# 4        False          False                  False           False
# 5        False          False                  False           False
# 6        False          False                  False           False
# 7        False          False                  False           False
# 8        False          False                  False           False
# 9        False          False                  False           False
# 10       False          False                  False           False
# 11       False          False                  False           False
# 12       False          False                  False           False
# ...

# %%
df.isnull().sum()
# Out:
# Continent                0
# ElevationZone            0
# UrbanRuralDesignation    0
# Population1990           0
# Population2000           0
# Population2010           0
# Population2100           0
# LandArea                 0
# dtype: int64

# %% [markdown]
# # 5. Find the average population size in the years 2000 and 2010.

# %%
average = (df['Population2000'].mean() + df ['Population2010'].mean())/2

# %%
average
# Out:
# 128618904.92916667

# %% [markdown]
# # 6. Check how many rows have UrbanRuralDesignation equal to “Urban”.

# %%
len(df["UrbanRuralDesignation"] == "Urban")
# Out:
# 120

# %%
sum(df['UrbanRuralDesignation'] == 'Urban')
# Out:
# 60

# %%
Count = 0
List = df.loc[:,"UrbanRuralDesignation"]=="Urban"

for item in List:
    if item == True:
        Count += 1

print(Count)
# Out:
# 60

# %%
List = df.loc[:,"UrbanRuralDesignation"]=="Urban"

# %%
List
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
# 5       True
# 6      False
# 7       True
# 8      False
# 9       True
# 10     False
# 11      True
# 12     False
# 13      True
# 14     False
# 15      True
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21      True
# 22     False
# 23      True
# 24     False
# 25      True
# 26     False
# 27      True
# 28     False
# 29      True
# 30     False
# 31      True
# 32     False
# 33      True
# 34     False
# 35      True
# 36     False
# 37      True
# 38     False
# 39      True
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50      True
# 51      True
# 52      True
# 53      True
# 54      True
# 55      True
# 56      True
# 57      True
# 58      True
# 59      True
# 60     False
# 61      True
# 62     False
# 63      True
# 64     False
# 65      True
# ...

# %%
df.loc[df.loc[:,"UrbanRuralDesignation"]=="Urban"].shape
# Out:
# (60, 8)

# %%
df.dtypes
# Out:
# Continent                object
# ElevationZone            object
# UrbanRuralDesignation    object
# Population1990            int64
# Population2000            int64
# Population2010            int64
# Population2100            int64
# LandArea                  int64
# dtype: object
